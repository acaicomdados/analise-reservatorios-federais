# %% [markdown]
# <a href="https://colab.research.google.com/github/acaicomdados/analise-reservatorios-federais/blob/main/An%C3%A1lise%20feito%20nos%20encontros/An%C3%A1lise%20s%C3%A9rie%20hist%C3%B3rica/Bacia%20Amazonas/Extraindo_serie_historica_amazonas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração das usinas relacionadas a bacia do amazonas
#
# Neste notebook vão ser extraidas as series históricas referentes as bacias do amazonas, em qu vai ser feita a análise exploratória da mesma depois da bacia do tocantins

# %%
# blibioteca base dos dados
# !pip install basedosdados

# %%
import numpy as np
import pandas as pd
import basedosdados as bd
import plotly.express as px

# %%
url = 'https://raw.githubusercontent.com/acaicomdados/analise-reservatorios-federais/main/Datasets/reservatorio_geral_codigo_aneel.csv'

reservatorios = pd.read_csv(url)
reservatorios.drop('Unnamed: 0',axis=1,inplace=True)
reservatorios.head()
# Out:
#          data subsistema id_empreendimento_aneel  \
# 0  2007-02-03        SUL   UHE.PH.SC.027401-1.01
# 1  2005-11-01        SUL   UHE.PH.RS.027556-5.01
# 2  2005-11-01        SUL   UHE.PH.RS.027556-5.01
# 3  2013-09-24        SUL   UHE.PH.SC.030415-8.01
# 4  2002-02-16        SUL   UHE.PH.SC.001356-0.01
#
#    id_reservatorio_planejamento  id_posto_vazao reservatorio_equivalente  \
# 0                             9             216                      SUL
# 1                            86             215                      SUL
# 2                            86             215                      SUL
# 3                            89              89                      SUL
# 4                            91             217                      SUL
#
#    reservatorio       tipo_reservatorio         usina    bacia  ...  \
# 0  CAMPOS NOVOS  RESERVATORIO COM USINA  CAMPOS NOVOS  URUGUAI  ...
# 1  BARRA GRANDE  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  ...
# ...

# %%
reservatorios = reservatorios[['bacia','codigo','rio','estado_sigla']]
reservatorios.head()
# Out:
#      bacia  codigo      rio estado_sigla
# 0  URUGUAI   19068   CANOAS           SC
# 1  URUGUAI   19067  PELOTAS           SC
# 2  URUGUAI   19067  PELOTAS           RS
# 3  URUGUAI   19147   CANOAS           SC
# 4  URUGUAI   19069  URUGUAI           SC

# %%
serie_reseravtorios = bd.read_table(dataset_id='br_ana_reservatorios',
table_id='sin',
billing_project_id="558244945046")
# Out:
# Downloading: 100%|██████████| 1157621/1157621 [01:58<00:00, 9728.44rows/s]

# %%
serie_reseravtorios = serie_reseravtorios[['data','id_reservatorio','nome_reservatorio','afluencia']]
serie_reseravtorios.head()
# Out:
#          data id_reservatorio nome_reservatorio  afluencia
# 0  2000-01-01           19001          CAMARGOS     222.10
# 1  2000-01-02           19001          CAMARGOS     296.77
# 2  2000-01-03           19001          CAMARGOS     361.46
# 3  2000-01-04           19001          CAMARGOS     461.70
# 4  2000-01-05           19001          CAMARGOS     416.50

# %%
reservatorios.rename(columns={'codigo':'id_reservatorio'},inplace=True)
reservatorios['id_reservatorio'] = reservatorios['id_reservatorio'].astype(str)
reservatorios.head()
# Out:
#      bacia id_reservatorio      rio estado_sigla
# 0  URUGUAI           19068   CANOAS           SC
# 1  URUGUAI           19067  PELOTAS           SC
# 2  URUGUAI           19067  PELOTAS           RS
# 3  URUGUAI           19147   CANOAS           SC
# 4  URUGUAI           19069  URUGUAI           SC

# %%
serie_reseravtorios = serie_reseravtorios.merge(reservatorios,on='id_reservatorio')
serie_reseravtorios.head()
# Out:
#          data id_reservatorio nome_reservatorio  afluencia   bacia     rio  \
# 0  2000-01-01           19001          CAMARGOS     222.10  GRANDE  GRANDE
# 1  2000-01-02           19001          CAMARGOS     296.77  GRANDE  GRANDE
# 2  2000-01-03           19001          CAMARGOS     361.46  GRANDE  GRANDE
# 3  2000-01-04           19001          CAMARGOS     461.70  GRANDE  GRANDE
# 4  2000-01-05           19001          CAMARGOS     416.50  GRANDE  GRANDE
#
#   estado_sigla
# 0           MG
# 1           MG
# 2           MG
# 3           MG
# 4           MG

# %%
serie_historica_amazonas = serie_reseravtorios[serie_reseravtorios['bacia']=='AMAZONAS']
serie_historica_amazonas.head()
# Out:
#                data id_reservatorio nome_reservatorio  afluencia     bacia  \
# 1176966  2000-01-01           19135     SANTO ANTONIO        NaN  AMAZONAS
# 1176967  2000-01-03           19135     SANTO ANTONIO        NaN  AMAZONAS
# 1176968  2000-01-04           19135     SANTO ANTONIO        NaN  AMAZONAS
# 1176969  2000-01-05           19135     SANTO ANTONIO        NaN  AMAZONAS
# 1176970  2000-01-06           19135     SANTO ANTONIO        NaN  AMAZONAS
#
#              rio estado_sigla
# 1176966  MADEIRA           RO
# 1176967  MADEIRA           RO
# 1176968  MADEIRA           RO
# 1176969  MADEIRA           RO
# 1176970  MADEIRA           RO

# %%
serie_historica_amazonas['data'] = pd.to_datetime(serie_historica_amazonas['data'])
serie_historica_amazonas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67140 entries, 1176966 to 1272541
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   data               67140 non-null  datetime64[ns]
#  1   id_reservatorio    67140 non-null  object
#  2   nome_reservatorio  67140 non-null  object
#  3   afluencia          54719 non-null  float64
#  4   bacia              67140 non-null  object
#  5   rio                67140 non-null  object
#  6   estado_sigla       67140 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 4.1+ MB

# %%
serie_historica_amazonas.reset_index(drop=True,inplace=True)
serie_historica_amazonas.head()
# Out:
#         data id_reservatorio nome_reservatorio  afluencia     bacia      rio  \
# 0 2000-01-01           19135     SANTO ANTONIO        NaN  AMAZONAS  MADEIRA
# 1 2000-01-03           19135     SANTO ANTONIO        NaN  AMAZONAS  MADEIRA
# 2 2000-01-04           19135     SANTO ANTONIO        NaN  AMAZONAS  MADEIRA
# 3 2000-01-05           19135     SANTO ANTONIO        NaN  AMAZONAS  MADEIRA
# 4 2000-01-06           19135     SANTO ANTONIO        NaN  AMAZONAS  MADEIRA
#
#   estado_sigla
# 0           RO
# 1           RO
# 2           RO
# 3           RO
# 4           RO

# %%
serie_historica_amazonas.to_csv('serie_historica_amazonas.csv')
