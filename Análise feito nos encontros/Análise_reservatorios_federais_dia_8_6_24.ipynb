# %% [markdown]
# <a href="https://colab.research.google.com/github/acaicomdados/analise-reservatorios-federais/blob/main/An%C3%A1lise_reservatorios_federais_dia_8_6_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Análise dos reservatótios federais
#
# Neste primeiro encontro será feito a formulação de hipoteses e uma análise inicial
#
# - **Objetivos**
#   - Fazer análise da vazão dos reservatorios, e ve houve um aumento uma que, ou se houve uma constante ao longo do tempo
#   - Fazer relação com dados de meteorologia e dados de geração de energia elétrica nas hidrelétricas
#
# - **Hipoteses a serem respondidas**
#   - Houve uma diminuição nos reservatorios brasileiros (com nesta noticia [aqui](https://www.cnnbrasil.com.br/nacional/brasil-perde-15-de-superficie-de-agua-desde-o-comeco-dos-anos-1990/))
#   - Há uma relação entre indices meteorologicos e vazão de água
#   - Há uma relação da vazão de água com a produção de energia nas hidrelétricas

# %%
# importar as blibiotecas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
url ='https://raw.githubusercontent.com/acaicomdados/analise-reservatorios-federais/main/Datasets/reservatorio_geral_codigo_aneel.csv'
reservatorio = pd.read_csv(url)
reservatorio.drop(['Unnamed: 0','id_empreendimento_aneel','id_reservatorio_planejamento','id_posto_vazao'],
                  axis=1,inplace=True)
reservatorio.head()
# Out:
#          data subsistema reservatorio_equivalente  reservatorio  \
# 0  2007-02-03        SUL                      SUL  CAMPOS NOVOS
# 1  2005-11-01        SUL                      SUL  BARRA GRANDE
# 2  2005-11-01        SUL                      SUL  BARRA GRANDE
# 3  2013-09-24        SUL                      SUL     GARIBALDI
# 4  2002-02-16        SUL                      SUL    MACHADINHO
#
#         tipo_reservatorio         usina    bacia      rio  cota_maxima  \
# 0  RESERVATORIO COM USINA  CAMPOS NOVOS  URUGUAI   CANOAS        660.0
# 1  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 2  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 3  RESERVATORIO COM USINA     GARIBALDI  URUGUAI   CANOAS        705.0
# 4  RESERVATORIO COM USINA    MACHADINHO  URUGUAI  URUGUAI        480.0
#
#    cota_minima  ...  volume_util  produtividade_especifica  \
# 0        655.0  ...       129.62                  0.009083
# 1        617.0  ...      2192.66                  0.009218
# 2        617.0  ...      2192.66                  0.009218
# 3        702.5  ...        64.23                  0.008626
# 4        465.0  ...      1055.81                  0.009034
#
#    produtividade_65_volume_util  tipo_perda  perda_carga   latitude  \
# 0                        1.6063           m         2.48 -27.603056
# 1                        1.4153           m         2.79 -27.777222
# 2                        1.4153           m         2.79 -27.777222
# 3                        0.3691           m         1.19 -27.624722
# 4                        0.8779           m         1.48 -27.524444
#
#    longitude  sistema  codigo estado_sigla
# 0 -51.323611      sin   19068           SC
# 1 -51.188611      sin   19067           SC
# 2 -51.188611      sin   19067           RS
# 3 -50.983889      sin   19147           SC
# 4 -51.788889      sin   19069           SC
#
# [5 rows x 22 columns]

# %%
reservatorio = reservatorio[reservatorio['sistema']=='sin']
reservatorio.shape
# Out:
# (175, 22)

# %%
reservatorio.drop(['sistema','codigo'],axis=1,inplace=True)
reservatorio.head()
# Out:
#          data subsistema reservatorio_equivalente  reservatorio  \
# 0  2007-02-03        SUL                      SUL  CAMPOS NOVOS
# 1  2005-11-01        SUL                      SUL  BARRA GRANDE
# 2  2005-11-01        SUL                      SUL  BARRA GRANDE
# 3  2013-09-24        SUL                      SUL     GARIBALDI
# 4  2002-02-16        SUL                      SUL    MACHADINHO
#
#         tipo_reservatorio         usina    bacia      rio  cota_maxima  \
# 0  RESERVATORIO COM USINA  CAMPOS NOVOS  URUGUAI   CANOAS        660.0
# 1  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 2  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 3  RESERVATORIO COM USINA     GARIBALDI  URUGUAI   CANOAS        705.0
# 4  RESERVATORIO COM USINA    MACHADINHO  URUGUAI  URUGUAI        480.0
#
#    cota_minima  volume_maximo  volume_minimo  volume_util  \
# 0        655.0        1477.00        1320.00       129.62
# 1        617.0        4904.45        2711.79      2192.66
# 2        617.0        4904.45        2711.79      2192.66
# 3        702.5         296.00         232.00        64.23
# 4        465.0        3340.00        2283.00      1055.81
#
#    produtividade_especifica  produtividade_65_volume_util tipo_perda  \
# 0                  0.009083                        1.6063          m
# 1                  0.009218                        1.4153          m
# 2                  0.009218                        1.4153          m
# 3                  0.008626                        0.3691          m
# 4                  0.009034                        0.8779          m
#
#    perda_carga   latitude  longitude estado_sigla
# 0         2.48 -27.603056 -51.323611           SC
# 1         2.79 -27.777222 -51.188611           SC
# 2         2.79 -27.777222 -51.188611           RS
# 3         1.19 -27.624722 -50.983889           SC
# 4         1.48 -27.524444 -51.788889           SC

# %%
plt.figure(figsize=(10,5))
plt.title('Estados onde se Localizam os reservatorios federais',
          fontsize=14)
sns.countplot(x='estado_sigla',data=reservatorio)
plt.xlabel('Estado')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
reservatorio['data'] = pd.to_datetime(reservatorio['data'],format='%Y-%m-%d')
reservatorio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 0 to 178
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          175 non-null    datetime64[ns]
#  1   subsistema                    175 non-null    object
#  2   reservatorio_equivalente      175 non-null    object
#  3   reservatorio                  175 non-null    object
#  4   tipo_reservatorio             175 non-null    object
#  5   usina                         175 non-null    object
#  6   bacia                         175 non-null    object
#  7   rio                           175 non-null    object
#  8   cota_maxima                   175 non-null    float64
#  9   cota_minima                   175 non-null    float64
#  10  volume_maximo                 175 non-null    float64
#  11  volume_minimo                 175 non-null    float64
#  12  volume_util                   175 non-null    float64
#  13  produtividade_especifica      175 non-null    float64
#  14  produtividade_65_volume_util  175 non-null    float64
#  15  tipo_perda                    175 non-null    object
#  16  perda_carga                   175 non-null    float64
#  17  latitude                      175 non-null    float64
#  18  longitude                     175 non-null    float64
#  19  estado_sigla                  175 non-null    object
# dtypes: datetime64[ns](1), float64(10), object(9)
# memory usage: 32.8+ KB

# %%
reservatorio['ano'] = reservatorio['data'].dt.year
reservatorio.head()
# Out:
#         data subsistema reservatorio_equivalente  reservatorio  \
# 0 2007-02-03        SUL                      SUL  CAMPOS NOVOS
# 1 2005-11-01        SUL                      SUL  BARRA GRANDE
# 2 2005-11-01        SUL                      SUL  BARRA GRANDE
# 3 2013-09-24        SUL                      SUL     GARIBALDI
# 4 2002-02-16        SUL                      SUL    MACHADINHO
#
#         tipo_reservatorio         usina    bacia      rio  cota_maxima  \
# 0  RESERVATORIO COM USINA  CAMPOS NOVOS  URUGUAI   CANOAS        660.0
# 1  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 2  RESERVATORIO COM USINA  BARRA GRANDE  URUGUAI  PELOTAS        647.0
# 3  RESERVATORIO COM USINA     GARIBALDI  URUGUAI   CANOAS        705.0
# 4  RESERVATORIO COM USINA    MACHADINHO  URUGUAI  URUGUAI        480.0
#
#    cota_minima  ...  volume_minimo  volume_util  produtividade_especifica  \
# 0        655.0  ...        1320.00       129.62                  0.009083
# 1        617.0  ...        2711.79      2192.66                  0.009218
# 2        617.0  ...        2711.79      2192.66                  0.009218
# 3        702.5  ...         232.00        64.23                  0.008626
# 4        465.0  ...        2283.00      1055.81                  0.009034
#
#    produtividade_65_volume_util  tipo_perda perda_carga   latitude  longitude  \
# 0                        1.6063           m        2.48 -27.603056 -51.323611
# 1                        1.4153           m        2.79 -27.777222 -51.188611
# 2                        1.4153           m        2.79 -27.777222 -51.188611
# 3                        0.3691           m        1.19 -27.624722 -50.983889
# 4                        0.8779           m        1.48 -27.524444 -51.788889
#
#    estado_sigla   ano
# 0            SC  2007
# 1            SC  2005
# 2            RS  2005
# 3            SC  2013
# 4            SC  2002
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(12,6))
plt.title('Ano em que foram criados os reservatorios federais',
          fontsize=14)
sns.histplot(x='ano',data=reservatorio,bins=30,kde=True)
plt.xlabel('Ano')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.figure(figsize=(10,5))
plt.title('Bacia hidrográficas onde se Localizam os reservatorios federais',
          fontsize=14)
sns.countplot(y='bacia',data=reservatorio)
plt.ylabel('Bacia')
plt.xlabel('Quantidade')
# Out:
# Text(0.5, 0, 'Quantidade')

# %%
plt.figure(figsize=(12,8))
plt.title('Rio onde se Localizam os reservatorios federais',
          fontsize=14)
sns.countplot(y='rio',data=reservatorio)
plt.ylabel('Rio')
plt.xlabel('Quantidade')
# Out:
# Text(0.5, 0, 'Quantidade')

# %%
plt.figure(figsize=(12,6))
plt.title('Cota máxima dos reservatorios federais',
          fontsize=14)
sns.histplot(x='cota_maxima',data=reservatorio,bins=30,kde=True)
plt.xlabel('Cota')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
reservatorio.describe()
# Out:
#                                 data  cota_maxima  cota_minima  volume_maximo  \
# count                            175   175.000000   175.000000     175.000000
# mean   1990-04-01 17:57:56.571428608   396.568114   389.817429    3606.150286
# min              1924-03-01 00:00:00    21.300000    20.300000       0.020000
# 25%              1973-03-01 00:00:00   245.750000   242.500000     116.915000
# 50%              1999-01-01 00:00:00   372.930000   371.430000     620.000000
# 75%              2006-06-29 00:00:00   552.000000   547.000000    3134.500000
# max              2023-04-28 00:00:00   913.000000   899.000000   54400.000000
# std                              NaN   217.645847   214.022039    7877.517201
#
#        volume_minimo   volume_util  produtividade_especifica  \
# count     175.000000    175.000000                175.000000
# mean     1921.155686   1929.575743                  0.008822
# min         0.010000      0.000000                  0.000000
# 25%        80.905000     14.610000                  0.008761
# 50%       450.000000    106.630000                  0.008917
# 75%      2169.660000    929.445000                  0.009019
# max     27695.190000  43250.000000                  0.009218
# std      4007.052164   5638.851955                  0.000700
#
#        produtividade_65_volume_util  perda_carga    latitude   longitude  \
# count                    175.000000   175.000000  175.000000  175.000000
# mean                       0.651339     1.484114  -18.760453  -48.919440
# min                        0.000000     0.000000  -29.449444  -64.648611
# 25%                        0.235500     0.325000  -22.940000  -51.908056
# 50%                        0.386900     0.750000  -20.126944  -49.492500
# 75%                        0.781800     1.540000  -16.211389  -46.383194
# max                        6.354200    23.780000    0.915278  -37.796944
# std                        0.839820     2.597611    6.909520    5.359592
#
#                ano
# count   175.000000
# mean   1989.885714
# min    1924.000000
# 25%    1973.000000
# 50%    1999.000000
# 75%    2006.000000
# max    2023.000000
# std      20.755793

# %%
plt.figure(figsize=(12,6))
plt.title('Cota minima dos reservatorios federais',
          fontsize=14)
sns.histplot(x='cota_minima',data=reservatorio,bins=30,kde=True)
plt.xlabel('Cota')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.figure(figsize=(12,6))
plt.title('Volume máximo dos reservatorios federais',
          fontsize=14)
sns.histplot(x='volume_maximo',data=reservatorio,bins=30,kde=True)
plt.xlabel('Volume')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.figure(figsize=(12,6))
plt.title('Volume minimo dos reservatorios federais',
          fontsize=14)
sns.histplot(x='volume_minimo',data=reservatorio,bins=30,kde=True)
plt.xlabel('Volume')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.figure(figsize=(12,6))
plt.title('Volume útil dos reservatorios federais',
          fontsize=14)
sns.histplot(x='volume_util',data=reservatorio,bins=30,kde=True)
plt.xlabel('Volume')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.figure(figsize=(12,6))
plt.title('MW ganhos em volume de queda nos reservatorios federais',
          fontsize=14)
sns.histplot(x='produtividade_especifica',data=reservatorio,bins=30,kde=True)
plt.xlabel('Volume')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
reservatorio.columns
# Out:
# Index(['data', 'subsistema', 'reservatorio_equivalente', 'reservatorio',
#        'tipo_reservatorio', 'usina', 'bacia', 'rio', 'cota_maxima',
#        'cota_minima', 'volume_maximo', 'volume_minimo', 'volume_util',
#        'produtividade_especifica', 'produtividade_65_volume_util',
#        'tipo_perda', 'perda_carga', 'latitude', 'longitude', 'estado_sigla',
#        'ano'],
#       dtype='object')

# %%
mapa_reservatorio = px.scatter_mapbox(reservatorio,lat='latitude',lon='longitude',hover_name='reservatorio',
                                      hover_data=['tipo_reservatorio','cota_minima','ano','bacia','rio'],
                                      title='reservatorios federais usado nas hidrelétricas')
mapa_reservatorio.update_layout(mapbox_style="open-street-map")
mapa_reservatorio.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="42a14d5b-bc21-4260-881f-ddc9612df23c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42a14d5b-bc21-4260-881f-ddc9612df23c")) {                    Plotly.newPlot(                        "42a14d5b-bc21-4260-881f-ddc9612df23c",                        [{"customdata":[["RESERVATORIO COM USINA",655.0,2007,"URUGUAI","CANOAS"],["RESERVATORIO COM USINA",617.0,2005,"URUGUAI","PELOTAS"],["RESERVATORIO COM USINA",617.0,2005,"URUGUAI","PELOTAS"],["RESERVATORIO COM USINA",702.5,2013,"URUGUAI","CANOAS"],["RESERVATORIO COM USINA",465.0,2002,"URUGUAI","URUGUAI"],["RESERVATORIO COM USINA",465.0,2002,"URUGUAI","URUGUAI"],["RESERVATORIO COM USINA",584.0,1973,"URUGUAI","PASSO FUNDO"],["FIO DAGUA",326.5,2009,"URUGUAI","PASSO FUNDO"],["RESERVATORIO COM USINA",544.0,2003,"URUGUAI","CHAPECO"],["FIO DAGUA",239.0,2008,"JACUI","TAQUARI-ANTAS"],["FIO DAGUA",147.0,2004,"JACUI","TAQUARI-ANTAS"],["FIO DAGUA",103.0,2008,"JACUI","TAQUARI-ANTAS"],["FIO DAGUA",153.67,2011,"URUGUAI","IJUI"],["FIO DAGUA",127.35,2012,"URUGUAI","IJUI"],["FIO DAGUA",264.0,2010,"URUGUAI","URUGUAI"],["FIO DAGUA",264.0,2010,"URUGUAI","URUGUAI"],["RESERVATORIO COM USINA",300.0,1973,"JACUI","JACUI"],["FIO DAGUA",270.37,1962,"JACUI","JACUI"],["FIO DAGUA",171.0,1978,"JACUI","JACUI"],["FIO DAGUA",91.0,2001,"JACUI","JACUI"],["RESERVATORIO COM USINA",822.0,1970,"CAPIVARI","CAPIVARI"],["FIO DAGUA",318.0,2009,"ITAJAI","ITAJAI"],["FIO DAGUA",151.0,2011,"TOCANTINS","TOCANTINS"],["RESERVATORIO COM USINA",51.6,1984,"TOCANTINS","TOCANTINS"],["RESERVATORIO COM USINA",626.0,2012,"PARANAPANEMA","TIBAGI"],["RESERVATORIO COM USINA",787.5,2005,"IGUACU","JORDAO"],["RESERVATORIO COM USINA",700.0,1980,"IGUACU","IGUACU"],["RESERVATORIO COM USINA",602.0,1992,"IGUACU","IGUACU"],["RESERVATORIO COM USINA",481.0,1980,"IGUACU","IGUACU"],["FIO DAGUA",389.0,1975,"IGUACU","IGUACU"],["FIO DAGUA",323.0,1999,"IGUACU","IGUACU"],["FIO DAGUA",219.0,1984,"PARANA","PARANA"],["FIO DAGUA",219.0,1987,"PARANA","PARANA"],["RESERVATORIO COM USINA",899.0,1960,"GRANDE","GRANDE"],["FIO DAGUA",511.8,1999,"GRANDE","GRANDE"],["FIO DAGUA",511.8,1999,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",785.0,2014,"PARANAIBA","SAO MARCOS"],["RESERVATORIO COM USINA",785.0,2014,"PARANAIBA","SAO MARCOS"],["FIO DAGUA",880.0,1955,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",570.0,1997,"PARANAIBA","CORUMBA"],["FIO DAGUA",807.8,2003,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",750.0,1963,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",653.12,1956,"GRANDE","GRANDE"],["FIO DAGUA",618.5,1969,"GRANDE","GRANDE"],["FIO DAGUA",618.5,1969,"GRANDE","GRANDE"],["FIO DAGUA",555.5,1971,"GRANDE","GRANDE"],["FIO DAGUA",555.5,1971,"GRANDE","GRANDE"],["FIO DAGUA",493.47,1985,"GRANDE","GRANDE"],["FIO DAGUA",493.47,1985,"GRANDE","GRANDE"],["FIO DAGUA",465.5,1973,"GRANDE","GRANDE"],["FIO DAGUA",465.5,1973,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",825.0,1952,"GRANDE","PARDO"],["FIO DAGUA",659.5,1980,"GRANDE","PARDO"],["FIO DAGUA",563.0,1980,"GRANDE","PARDO"],["RESERVATORIO COM USINA",426.0,1975,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",426.0,1975,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",373.3,1978,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",373.3,1978,"GRANDE","GRANDE"],["RESERVATORIO COM USINA",775.5,1994,"PARANAIBA","PARANAIBA"],["RESERVATORIO COM USINA",693.0,1998,"PARANAIBA","ARAGUARI-MG"],["RESERVATORIO COM USINA",623.3,2006,"PARANAIBA","ARAGUARI-MG"],["FIO DAGUA",564.7,2007,"PARANAIBA","ARAGUARI-MG"],["RESERVATORIO COM USINA",837.0,2006,"PARANAIBA","CORUMBA"],["RESERVATORIO COM USINA",576.5,2006,"PARANAIBA","CORRENTE"],["RESERVATORIO COM USINA",495.0,1980,"PARANAIBA","PARANAIBA"],["RESERVATORIO COM USINA",495.0,1980,"PARANAIBA","PARANAIBA"],["FIO DAGUA", ...

# %% [markdown]
# A partir dessa informações da análise, podemos fazer as seguintes questões
#
# - Os Estado onde se tem mais reservatorio implica em mais prdoução de energia elétrica (referente as hidrelétricas)?
# - O volume do reservatorio influencia na produção de energia elétrica?
# - A altura também influencia na produção de energia elétrica?
# - Pode fazer comparação da localização dos reservatorios com com as estações meteorologicas
