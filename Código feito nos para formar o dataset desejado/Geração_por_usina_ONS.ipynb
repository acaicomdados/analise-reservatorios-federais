# %% [markdown]
# <a href="https://colab.research.google.com/github/acaicomdados/analise-reservatorios-federais/blob/main/C%C3%B3digo%20feito%20nos%20para%20formar%20o%20dataset%20desejado/Gera%C3%A7%C3%A3o_por_usina_ONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install basedosdados

# %%
import basedosdados as bd
import pandas as pd
import numpy as np

# %%
gera = bd.read_sql("SELECT *FROM `basedosdados.br_ons_avaliacao_operacao.geracao_usina`WHERE tipo_usina = 'HIDROELETRICA'",
                   billing_project_id="868170289920")
gera.head()
# Out:
# Downloading: 100%|██████████| 34279050/34279050 [1:06:39<00:00, 8570.16rows/s]
#          data      hora   ano  mes sigla_uf id_subsistema subsistema  \
# 0  2012-12-22  20:00:00  2012   12       SC             S        SUL
# 1  2012-12-24  12:00:00  2012   12       SC             S        SUL
# 2  2012-12-01  12:00:00  2012   12       RO            SE    SUDESTE
# 3  2012-12-30  00:00:00  2012   12       GO            SE    SUDESTE
# 4  2012-12-26  23:00:00  2012   12       RS             S        SUL
#
#   id_empreendimento_aneel                            usina     tipo_usina  \
# 0    UHE.PH.SC.0274011.01                     Campos Novos  HIDROELETRICA
# 1    UHE.PH.SC.0274011.01                     Campos Novos  HIDROELETRICA
# 2    UHE.PH.RO.0297070.01                    Santo Antonio  HIDROELETRICA
# 3    UHE.PH.GO.0287601.01            Salto do Rio Verdinho  HIDROELETRICA
# 4    PCH.PH.RS.0292451.01  Engenheiro Ernesto Jorge Dreher  HIDROELETRICA
#
# ...

# %%
gera.drop(['hora','id_subsistema','tipo_usina','tipo_combustivel'],axis=1,
          inplace=True)
gera.head()
# Out:
#          data   ano  mes sigla_uf subsistema id_empreendimento_aneel  \
# 0  2012-12-22  2012   12       SC        SUL    UHE.PH.SC.0274011.01
# 1  2012-12-24  2012   12       SC        SUL    UHE.PH.SC.0274011.01
# 2  2012-12-01  2012   12       RO    SUDESTE    UHE.PH.RO.0297070.01
# 3  2012-12-30  2012   12       GO    SUDESTE    UHE.PH.GO.0287601.01
# 4  2012-12-26  2012   12       RS        SUL    PCH.PH.RS.0292451.01
#
#                              usina tipo_modalidade_operacao       geracao
# 0                     Campos Novos                   TIPO I  0.000000e+00
# 1                     Campos Novos                   TIPO I  0.000000e+00
# 2                    Santo Antonio                   TIPO I  2.386930e+10
# 3            Salto do Rio Verdinho                   TIPO I  4.651000e+09
# 4  Engenheiro Ernesto Jorge Dreher                TIPO II-C  1.770000e+09

# %%
gera.to_csv('/content/drive/MyDrive/Datasets/geração energia hidreletica.csv')]
